# %% [markdown]
# # Importing Required Libraries and Data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime

# %matplotlib inline

# %%
df = pd.read_csv('C:\\Users\\Vijay\\Desktop\\Uber_Data.csv')
df.head()
# Out:
#           pickup_dt    borough  pickups  spd   vsb  temp  dewp     slp  pcp01  \
# 0  01-01-2015 01:00      Bronx      152  5.0  10.0  30.0   7.0  1023.5    0.0
# 1  01-01-2015 01:00   Brooklyn     1519  5.0  10.0   NaN   7.0  1023.5    0.0
# 2  01-01-2015 01:00        EWR        0  5.0  10.0  30.0   7.0  1023.5    0.0
# 3  01-01-2015 01:00  Manhattan     5258  5.0  10.0  30.0   7.0  1023.5    0.0
# 4  01-01-2015 01:00     Queens      405  5.0  10.0  30.0   7.0  1023.5    0.0
#
#    pcp06  pcp24   sd hday
# 0    0.0    0.0  0.0    Y
# 1    0.0    0.0  0.0    Y
# 2    0.0    0.0  0.0    Y
# 3    0.0    0.0  0.0    Y
# 4    0.0    0.0  0.0    Y

# %% [markdown]
# ### Data Preprocessing

# %%
missing_value=["NA","nan"," ","NaN"]
df1 = pd.read_csv('C:\\Users\\Vijay\\Desktop\\Uber_Data.csv',na_values=missing_value)

# %%
df1.isnull().sum()
# Out:
# pickup_dt       0
# borough      3043
# pickups         0
# spd             0
# vsb             0
# temp          359
# dewp            0
# slp             0
# pcp01           0
# pcp06           0
# pcp24           0
# sd              0
# hday            0
# dtype: int64

# %% [markdown]
# ### Using Heatmap for better visualisation

# %%
sns.heatmap(df1.isnull(), yticklabels=False)

# %%
## Using interplotion handling the missing data in tempature column
df1 =df1.interpolate()

# %%
df1.head()
# Out:
#           pickup_dt    borough  pickups  spd   vsb  temp  dewp     slp  pcp01  \
# 0  01-01-2015 01:00      Bronx      152  5.0  10.0  30.0   7.0  1023.5    0.0
# 1  01-01-2015 01:00   Brooklyn     1519  5.0  10.0  30.0   7.0  1023.5    0.0
# 2  01-01-2015 01:00        EWR        0  5.0  10.0  30.0   7.0  1023.5    0.0
# 3  01-01-2015 01:00  Manhattan     5258  5.0  10.0  30.0   7.0  1023.5    0.0
# 4  01-01-2015 01:00     Queens      405  5.0  10.0  30.0   7.0  1023.5    0.0
#
#    pcp06  pcp24   sd hday
# 0    0.0    0.0  0.0    Y
# 1    0.0    0.0  0.0    Y
# 2    0.0    0.0  0.0    Y
# 3    0.0    0.0  0.0    Y
# 4    0.0    0.0  0.0    Y

# %% [markdown]
# ### Using this HeatMap we can see the Null Values in a specific columns

# %%
sns.heatmap(df1.isnull(), yticklabels=False)

# %% [markdown]
# ### Here we can see there are still nan value in pickups columns

# %%
df1.borough.unique()
# Out:
# array(['Bronx', 'Brooklyn', 'EWR', 'Manhattan', 'Queens', 'Staten Island',
#        nan], dtype=object)

# %%
df1 = df1.dropna()
df1 = df1.reset_index(drop=True)
df1.head()
# Out:
#           pickup_dt    borough  pickups  spd   vsb  temp  dewp     slp  pcp01  \
# 0  01-01-2015 01:00      Bronx      152  5.0  10.0  30.0   7.0  1023.5    0.0
# 1  01-01-2015 01:00   Brooklyn     1519  5.0  10.0  30.0   7.0  1023.5    0.0
# 2  01-01-2015 01:00        EWR        0  5.0  10.0  30.0   7.0  1023.5    0.0
# 3  01-01-2015 01:00  Manhattan     5258  5.0  10.0  30.0   7.0  1023.5    0.0
# 4  01-01-2015 01:00     Queens      405  5.0  10.0  30.0   7.0  1023.5    0.0
#
#    pcp06  pcp24   sd hday
# 0    0.0    0.0  0.0    Y
# 1    0.0    0.0  0.0    Y
# 2    0.0    0.0  0.0    Y
# 3    0.0    0.0  0.0    Y
# 4    0.0    0.0  0.0    Y

# %%
df1.isnull().sum()
# Out:
# pickup_dt    0
# borough      0
# pickups      0
# spd          0
# vsb          0
# temp         0
# dewp         0
# slp          0
# pcp01        0
# pcp06        0
# pcp24        0
# sd           0
# hday         0
# dtype: int64

# %%
df1.borough.unique()
# Out:
# array(['Bronx', 'Brooklyn', 'EWR', 'Manhattan', 'Queens', 'Staten Island'],
#       dtype=object)

# %%
df1.head()
# Out:
#           pickup_dt    borough  pickups  spd   vsb  temp  dewp     slp  pcp01  \
# 0  01-01-2015 01:00      Bronx      152  5.0  10.0  30.0   7.0  1023.5    0.0
# 1  01-01-2015 01:00   Brooklyn     1519  5.0  10.0  30.0   7.0  1023.5    0.0
# 2  01-01-2015 01:00        EWR        0  5.0  10.0  30.0   7.0  1023.5    0.0
# 3  01-01-2015 01:00  Manhattan     5258  5.0  10.0  30.0   7.0  1023.5    0.0
# 4  01-01-2015 01:00     Queens      405  5.0  10.0  30.0   7.0  1023.5    0.0
#
#    pcp06  pcp24   sd hday
# 0    0.0    0.0  0.0    Y
# 1    0.0    0.0  0.0    Y
# 2    0.0    0.0  0.0    Y
# 3    0.0    0.0  0.0    Y
# 4    0.0    0.0  0.0    Y

# %%
df2 =df1.loc[df1['pickups'] != 0]
df2= df2.reset_index(drop=True)

# %%
df2.head()
# Out:
#           pickup_dt        borough  pickups  spd   vsb  temp  dewp     slp  \
# 0  01-01-2015 01:00          Bronx      152  5.0  10.0  30.0   7.0  1023.5
# 1  01-01-2015 01:00       Brooklyn     1519  5.0  10.0  30.0   7.0  1023.5
# 2  01-01-2015 01:00      Manhattan     5258  5.0  10.0  30.0   7.0  1023.5
# 3  01-01-2015 01:00         Queens      405  5.0  10.0  30.0   7.0  1023.5
# 4  01-01-2015 01:00  Staten Island        6  5.0  10.0  30.0   7.0  1023.5
#
#    pcp01  pcp06  pcp24   sd hday
# 0    0.0    0.0    0.0  0.0    Y
# 1    0.0    0.0    0.0  0.0    Y
# 2    0.0    0.0    0.0  0.0    Y
# 3    0.0    0.0    0.0  0.0    Y
# 4    0.0    0.0    0.0  0.0    Y

# %%
##successfully we have cleared the Null Values
sns.heatmap(df2.isnull(), yticklabels=False)

# %%
df2.describe()
# Out:
#             pickups           spd           vsb          temp          dewp  \
# count  20491.000000  20491.000000  20491.000000  20491.000000  20491.000000
# mean     695.891513      5.968327      8.831201     47.842064     30.968121
# std     1124.672723      3.691154      2.425371     19.823750     21.307818
# min        1.000000      0.000000      0.000000      2.000000    -16.000000
# 25%       42.000000      3.000000      9.100000     32.000000     14.000000
# 50%      282.000000      6.000000     10.000000     46.000000     30.000000
# 75%      643.000000      8.000000     10.000000     65.000000     50.000000
# max     7883.000000     21.000000     10.000000     89.000000     73.000000
#
#                 slp         pcp01         pcp06         pcp24            sd
# count  20491.000000  20491.000000  20491.000000  20491.000000  20491.000000
# mean    1017.804851      0.003742      0.025505      0.090062      2.504318
# ...

# %%
df2.corr()
# Out:
#           pickups       spd       vsb      temp      dewp       slp     pcp01  \
# pickups  1.000000  0.016788 -0.012809  0.063490  0.037757 -0.017867  0.008498
# spd      0.016788  1.000000  0.100633 -0.292457 -0.321362 -0.086405 -0.003572
# vsb     -0.012809  0.100633  1.000000  0.019085 -0.235982  0.161955 -0.483060
# temp     0.063490 -0.292457  0.019085  1.000000  0.897060 -0.225671 -0.011994
# dewp     0.037757 -0.321362 -0.235982  0.897060  1.000000 -0.310614  0.114734
# slp     -0.017867 -0.086405  0.161955 -0.225671 -0.310614  1.000000 -0.085588
# pcp01    0.008498 -0.003572 -0.483060 -0.011994  0.114734 -0.085588  1.000000
# pcp06    0.000489  0.015373 -0.113129 -0.033386  0.014584 -0.103417  0.118533
# pcp24   -0.024344 -0.010810 -0.001108 -0.012507  0.003205 -0.131825  0.001815
# sd      -0.006974  0.101399 -0.046952 -0.550115 -0.493619  0.121952 -0.002025
#
#             pcp06     pcp24        sd
# pickups  0.000489 -0.024344 -0.006974
# ...

# %%
# Using Perason Correlation
import seaborn as sns
import matplotlib.cm as cm
plt.figure(figsize=(12,10))
cor = df2.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.RdYlBu_r)
plt.show()

# %%
# with the following function we can select highly correlated features
# it will remove the first feature that is correlated with anything other feature

def correlation(df2, threshold):
    col_corr = set()  # Set of all the names of correlated columns
    corr_matrix = df2.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold: # we are interested in absolute coeff value
                colname = corr_matrix.columns[i]  # getting the name of column
                col_corr.add(colname)
    return col_corr

# %%
corr_features = correlation(df2, 0.7)
len(set(corr_features))
# Out:
# 1

# %%
corr_features
# Out:
# {'dewp'}

# %%
df2 = df2.drop(corr_features,axis=1)

# %%
df2.head()
# Out:
#           pickup_dt        borough  pickups  spd   vsb  temp     slp  pcp01  \
# 0  01-01-2015 01:00          Bronx      152  5.0  10.0  30.0  1023.5    0.0
# 1  01-01-2015 01:00       Brooklyn     1519  5.0  10.0  30.0  1023.5    0.0
# 2  01-01-2015 01:00      Manhattan     5258  5.0  10.0  30.0  1023.5    0.0
# 3  01-01-2015 01:00         Queens      405  5.0  10.0  30.0  1023.5    0.0
# 4  01-01-2015 01:00  Staten Island        6  5.0  10.0  30.0  1023.5    0.0
#
#    pcp06  pcp24   sd hday
# 0    0.0    0.0  0.0    Y
# 1    0.0    0.0  0.0    Y
# 2    0.0    0.0  0.0    Y
# 3    0.0    0.0  0.0    Y
# 4    0.0    0.0  0.0    Y

# %%
##As we can see now there are no corelated values now

# %%
import seaborn as sns
import matplotlib.cm as cm
plt.figure(figsize=(12,10))
cor = df2.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.RdGy_r)
plt.show()

# %%
#Using Box plot for checking values
df2.plot.box()
plt.yticks(list(range(len(df2.columns))), df2.columns, rotation='vertical')
# Out:
# ([<matplotlib.axis.YTick at 0x2149e64c788>,
# ...
#  <a list of 12 Text yticklabel objects>)

# %%
plt.plot(df2.slp.values)

# %%
#As we can see in Dtyes the Pickup column is object then converting it in DateTime for Beteer analysis
df2['pickup_date']=pd.to_datetime(df2['pickup_dt'],infer_datetime_format=True)
df2 = df2.drop(columns='pickup_dt')

# %%
df2.dtypes
# Out:
# borough                object
# pickups                 int64
# spd                   float64
# vsb                   float64
# temp                  float64
# slp                   float64
# pcp01                 float64
# pcp06                 float64
# pcp24                 float64
# sd                    float64
# hday                   object
# pickup_date    datetime64[ns]
# dtype: object

# %%
np.unique(df2.hday)
# Out:
# array(['N', 'Y'], dtype=object)

# %%
df2.head()
# Out:
#          borough  pickups  spd   vsb  temp     slp  pcp01  pcp06  pcp24   sd  \
# 0          Bronx      152  5.0  10.0  30.0  1023.5    0.0    0.0    0.0  0.0
# 1       Brooklyn     1519  5.0  10.0  30.0  1023.5    0.0    0.0    0.0  0.0
# 2      Manhattan     5258  5.0  10.0  30.0  1023.5    0.0    0.0    0.0  0.0
# 3         Queens      405  5.0  10.0  30.0  1023.5    0.0    0.0    0.0  0.0
# 4  Staten Island        6  5.0  10.0  30.0  1023.5    0.0    0.0    0.0  0.0
#
#   hday         pickup_date
# 0    Y 2015-01-01 01:00:00
# 1    Y 2015-01-01 01:00:00
# 2    Y 2015-01-01 01:00:00
# 3    Y 2015-01-01 01:00:00
# 4    Y 2015-01-01 01:00:00

# %%
df2['date']=df2['pickup_date'].dt.day
df2['weekday']=df2['pickup_date'].dt.day_name()
df2['hour']=df2['pickup_date'].dt.hour

# %%
df2.head()
# Out:
#          borough  pickups  spd   vsb  temp     slp  pcp01  pcp06  pcp24   sd  \
# 0          Bronx      152  5.0  10.0  30.0  1023.5    0.0    0.0    0.0  0.0
# 1       Brooklyn     1519  5.0  10.0  30.0  1023.5    0.0    0.0    0.0  0.0
# 2      Manhattan     5258  5.0  10.0  30.0  1023.5    0.0    0.0    0.0  0.0
# 3         Queens      405  5.0  10.0  30.0  1023.5    0.0    0.0    0.0  0.0
# 4  Staten Island        6  5.0  10.0  30.0  1023.5    0.0    0.0    0.0  0.0
#
#   hday         pickup_date  date   weekday  hour
# 0    Y 2015-01-01 01:00:00     1  Thursday     1
# 1    Y 2015-01-01 01:00:00     1  Thursday     1
# 2    Y 2015-01-01 01:00:00     1  Thursday     1
# 3    Y 2015-01-01 01:00:00     1  Thursday     1
# 4    Y 2015-01-01 01:00:00     1  Thursday     1

# %%
week_day=pd.DataFrame(df2['weekday'].value_counts())
week_day
# Out:
#            weekday
# Friday        3084
# Saturday      2962
# Thursday      2950
# Sunday        2943
# Tuesday       2901
# Wednesday     2838
# Monday        2813

# %% [markdown]
# ## Permforming EDA on Data

# %%
week_day.plot.bar()
plt.title('Total Uber pickups by Weekdays')
plt.xlabel('Weekday')
plt.ylabel('Frequency')
plt.show()

# %%
city_df2=pd.DataFrame(df2['borough'].value_counts())
city_df2
# Out:
#                borough
# Queens            4335
# Manhattan         4335
# Brooklyn          4335
# Bronx             4334
# Staten Island     3052
# EWR                100

# %%
city_df2.plot.bar()
plt.title('Total Uber pickups by City')
plt.xlabel('Cities')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# #### Here as we can see city EWR does not play an important role so dropping

# %%
df2 = df2[df2.borough != 'EWR']

# %%
df2.groupby('borough').size().plot(kind='pie', autopct='%.2f')

# %%
week_day['day_type']=['wd','we','wd','we','wd','wd','wd']
week_day
# Out:
#            weekday day_type
# Friday        3084       wd
# Saturday      2962       we
# Thursday      2950       wd
# Sunday        2943       we
# Tuesday       2901       wd
# Wednesday     2838       wd
# Monday        2813       wd

# %%
pie=week_day.groupby('day_type').sum()
pie.iloc[0,0]=pie.iloc[0,0]/5
pie.iloc[1,0]=pie.iloc[1,0]/2
pie
# Out:
#           weekday
# day_type
# wd         2917.2
# we         2952.5

# %%
explode=[0,0.05]
colors=['cyan','gold']
labels=['Weekday','Weekend']
pie.plot.pie(autopct = '%1.1f%%',shadow=True,subplots=True,
        colors=colors,explode=explode)
plt.legend(labels=labels)
plt.show()

# %% [markdown]
# ##### As we see above the Datatype of pickup_dt is object converting it into DateTime for further analysis

# %%
hour=df2.groupby('hour').count()

# %%
hour=pd.DataFrame(hour['borough'])
hour.columns=['Frequency']
hour
# Out:
#       Frequency
# hour
# 0           814
# 1           823
# 2           804
# 3           780
# 4           794
# 5           810
# 6           816
# 7           844
# 8           860
# 9           863
# 10          873
# 11          861
# 12          863
# 13          859
# 14          869
# 15          885
# 16          879
# 17          882
# 18          877
# 19          872
# 20          871
# 21          866
# 22          872
# 23          854

# %%
hour.plot.bar()
plt.ylabel('Frequency')
plt.title('Uber pickups by hour')
plt.show()

# %%
explode=[0,0.06]
colors=['cyan','gold']
labels=['wd','we']
pie.plot.pie(autopct = '%1.1f%%',shadow=True,subplots=True,
        colors=colors,explode=explode)
plt.legend(labels=labels)
plt.show()

# %%
df2.head()
# Out:
#          borough  pickups  spd   vsb  temp     slp  pcp01  pcp06  pcp24   sd  \
# 0          Bronx      152  5.0  10.0  30.0  1023.5    0.0    0.0    0.0  0.0
# 1       Brooklyn     1519  5.0  10.0  30.0  1023.5    0.0    0.0    0.0  0.0
# 2      Manhattan     5258  5.0  10.0  30.0  1023.5    0.0    0.0    0.0  0.0
# 3         Queens      405  5.0  10.0  30.0  1023.5    0.0    0.0    0.0  0.0
# 4  Staten Island        6  5.0  10.0  30.0  1023.5    0.0    0.0    0.0  0.0
#
#   hday         pickup_date  date   weekday  hour
# 0    Y 2015-01-01 01:00:00     1  Thursday     1
# 1    Y 2015-01-01 01:00:00     1  Thursday     1
# 2    Y 2015-01-01 01:00:00     1  Thursday     1
# 3    Y 2015-01-01 01:00:00     1  Thursday     1
# 4    Y 2015-01-01 01:00:00     1  Thursday     1

# %% [markdown]
# ### Multivariate Analysis

# %%
sns.pairplot(df2)

# %% [markdown]
# ### Using more data cleaning and mertices we create more effecient data visualisation, However due to the Time constraint here are the EDA I came up with
